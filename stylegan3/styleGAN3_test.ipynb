# %% [markdown]
# Setup

# %%
# Required for StyleGAN3
# !pip install einops ninja gdown
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 973.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# Connect Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
if os.path.isdir('/content/drive/MyDrive/Capstone/stylegan3/'):
  # %cd '/content/drive/MyDrive/Capstone/stylegan3/'
else:
  # !git clone https://github.com/NVlabs/stylegan3 /content/drive/MyDrive/Capstone/stylegan3/
  # %cd '/content/drive/MyDrive/Capstone/stylegan3/'
# Out:
# /content/drive/MyDrive/Capstone/stylegan3

# %% [markdown]
# Pre-process dataset

# %%
#!python dataset_tool.py --source=/content/drive/MyDrive/Capstone/dataset/ --dest=/content/drive/MyDrive/Capstone/stylegan3/datasets/dataset_512.zip --resolution='512x512'

# %% [markdown]
# Training

# %%
# Parameters
outdir = '--outdir=/content/drive/MyDrive/Capstone/stylegan3/results7'
cfg = '--cfg=stylegan3-t'
#cfg = '--cfg=stylegan3-r'
data = '--data=/content/drive/MyDrive/Capstone/stylegan3/datasets/dataset_512.zip'
resume = '--resume=/content/drive/MyDrive/Capstone/stylegan3/results6/00000-stylegan3-t-dataset_512-gpus1-batch32-gamma8.2/network-snapshot-000330.pkl'

gpus = '--gpus=1'
batch = '--batch=32'
#batch = '--batch=16
batch_gpu = '--batch-gpu=8'

gamma = '--gamma=8.2'
#gamma = '--gamma=10'
mirror = '--mirror=0'
#mirror = '--mirror=1'
kimg = '--kimg=1000'
tick = '--tick=2'
snap = '--snap=4'
workers = '--workers=2'

# %%
# !python /content/drive/MyDrive/Capstone/stylegan3/train.py {outdir} {cfg} {data} {resume} {gpus} {batch} {batch_gpu} {gamma} {mirror} {kimg} {tick} {snap}
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9988915792636801
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
# ...

# %% [markdown]
# Generate

# %%
# Parameters
outdir = '--outdir=/content/drive/MyDrive/Capstone/stylegan3/out2'
trunc = '--trunc=1'
seeds = '--seeds=11,12,14-16'
network = '--network=/content/drive/MyDrive/Capstone/stylegan3/results3/00000-stylegan3-r-dataset_512-gpus1-batch16-gamma10/network-snapshot-000020.pkl'

# %%
#!python /content/drive/MyDrive/Capstone/stylegan3/gen_images.py {outdir} {trunc} {seeds} {network}
